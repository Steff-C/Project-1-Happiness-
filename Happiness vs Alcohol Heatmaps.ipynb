# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import gmaps
import os

# Import API key
from config import g_key

# %%
# Load csv and preview
happiness_df = pd.read_csv('output_data/alcohol_vs_happiness.csv')
happiness_df
# Out:
#      Unnamed: 0                   Country  GDP (per capita PPP)  HDI Rank  \
# 0             0                Luxembourg              114110.0      23.0
# 1             1                 Singapore               97745.0      11.0
# 2             2                     Qatar               94503.0      45.0
# 3             3                   Ireland               83471.0       2.0
# 4             4               Switzerland               68479.0       2.0
# ..          ...                       ...                   ...       ...
# 128         128                Mozambique                1290.0     181.0
# 129         129                     Niger                1196.0     189.0
# 130         130                    Malawi                1043.0     174.0
# 131         131  Central African Republic                 933.0     188.0
# 132         132                   Burundi                 762.0     185.0
#
#        HDI  Life Expectancy  Overall rank  Score  GDP per capita  \
# 0    0.913             82.1            17  6.910           1.576
# 1    0.936             83.5            34  6.343           1.529
# 2    0.845             80.1            32  6.374           1.649
# 3    0.951             82.1            14  6.977           1.448
# 4    0.955             83.6             5  7.487           1.420
# ..     ...              ...           ...    ...             ...
# 128  0.452             60.2           123  4.417           0.198
# 129  0.391             62.0           134  4.166           0.131
# 130  0.478             63.8           147  3.587           0.186
# 131  0.395             52.8           155  3.083           0.024
# 132  0.431             61.2           156  2.905           0.091
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.520                    0.896                         0.632
# 1             1.451                    1.008                         0.631
# 2             1.303                    0.748                         0.654
# 3             1.583                    0.876                         0.614
# 4             1.549                    0.927                         0.660
# ..              ...                      ...                           ...
# 128           0.902                    0.173                         0.531
# 129           0.867                    0.221                         0.390
# 130           0.541                    0.306                         0.531
# 131           0.000                    0.010                         0.305
# 132           0.627                    0.145                         0.065
#
#      Generosity  Perceptions of corruption  All types  Beer  Spirits  Wine  \
# 0         0.196                      0.321      10.94  4.03     2.21  4.70
# 1         0.261                      0.457       1.85  1.25     0.27  0.30
# 2         0.256                      0.171       1.02  0.30     0.64  0.08
# 3         0.307                      0.306      11.20  5.12     2.32  2.90
# 4         0.256                      0.357       9.51  3.17     1.65  4.23
# ..          ...                        ...        ...   ...      ...   ...
# 128       0.206                      0.158       1.24  1.00     0.21  0.03
# 129       0.175                      0.099       0.13  0.04     0.07  0.02
# 130       0.210                      0.080       2.00  0.17     0.19  0.02
# 131       0.218                      0.038       0.88  0.51     0.03  0.02
# 132       0.149                      0.076       4.00  1.81     0.01  0.00
#
#      Other
# 0     0.00
# 1     0.04
# 2     0.01
# 3     0.85
# 4     0.12
# ..     ...
# 128   0.01
# 129   0.00
# 130   1.61
# 131   0.32
# 132   2.18
#
# [133 rows x 19 columns]

# %%
# Target country
country = happiness_df["Country"].to_list()


# Define the endpoint URL
base_url = 'https://maps.googleapis.com/maps/api/geocode/json?'

lat = []
lng = []


for country in country:
 
    
    # Build partial query URL
    query_url = f'{base_url}address={country}&key={g_key}'
    response = requests.get(query_url).json()

    
    
    lat.append(response['results'][0]['geometry']['location']['lat'])
    lng.append(response['results'][0]['geometry']['location']['lng'])

# %%
# Fix Lat/Lng for Georgia - the country

lat[67] = 42.3154
lng[67] = 43.3569

consumption = happiness_df["All types"].to_list()
country = happiness_df["Country"].to_list()
happiness = happiness_df["Score"].to_list()
happy_dict = {
    "Country": country,
    "Lat": lat,
    "Lng": lng,
    "Alcohol Consumption": consumption,
    "Happiness": happiness
   
}
happy_data = pd.DataFrame(happy_dict)

top = happy_data.sort_values(by="Country", ascending=False)

top.tail(50)
# Out:
#                       Country        Lat         Lng  Alcohol Consumption  \
# 122                     Haiti  18.971187  -72.285215                 2.74
# 115                    Guinea   9.945587   -9.696645                 0.31
# 89                  Guatemala  15.783471  -90.230759                 1.62
# 39                     Greece  39.074208   21.824312                 6.10
# 97                      Ghana   7.946527   -1.023194                 1.56
# 12                    Germany  51.165691   10.451526                10.81
# 67                    Georgia  42.315400   43.356900                 5.44
# 63                      Gabon  -0.803689   11.609444                 7.16
# 22                     France  46.227638    2.213749                11.24
# 18                    Finland  61.924110   25.748151                 8.37
# 120                  Ethiopia   9.145000   40.489673                 0.95
# 32                    Estonia  58.595272   25.013607                11.20
# 87                El Salvador  13.794185  -88.896530                 2.82
# 80                      Egypt  26.820553   30.802498                 0.13
# 77                    Ecuador  -1.831239  -78.183406                 3.16
# 56         Dominican Republic  18.735693  -70.162651                 5.54
# 10                    Denmark  56.263920    9.501785                 9.31
# 29                     Cyprus  35.126413   33.429859                 9.59
# 42                    Croatia  45.100000   15.200000                10.10
# 53                 Costa Rica   9.748917  -83.753428                 3.79
# 65                   Colombia   4.570868  -74.297333                 4.29
# 60                      China  35.861660  104.195397                 5.62
# 46                      Chile -35.675147  -71.542969                 7.84
# 125                      Chad  15.454166   18.732207                 0.42
# 131  Central African Republic   6.611111   20.939444                 0.88
# 17                     Canada  56.130366 -106.346771                 8.20
# 107                  Cameroon   7.369722   12.354722                 4.19
# 106                  Cambodia  12.565679  104.990963                 3.70
# 132                   Burundi  -3.373056   29.918886                 4.00
# 118              Burkina Faso  12.238333   -1.561593                 7.20
# 49                   Bulgaria  42.733883   25.485830                11.42
# 64                     Brazil -14.235004  -51.925280                 6.19
# 57                   Botswana -22.328474   24.684866                 4.81
# 66     Bosnia and Herzegovina  43.915886   17.679076                 4.99
# 81                     Bhutan  27.514162   90.433601                 0.06
# 112                     Benin   9.307690    2.315834                 1.37
# 91                     Belize  17.189877  -88.497650                 5.61
# 14                    Belgium  50.503887    4.469936                 9.42
# 54                    Belarus  53.709807   27.953389                10.09
# 103                Bangladesh  23.684994   90.356331                 0.00
# 21                    Bahrain  26.066700   50.557700                 1.23
# 68                 Azerbaijan  40.143105   47.576927                 2.92
# 11                    Austria  47.516231   14.550072                11.80
# 16                  Australia -25.274398  133.775136                 9.51
# 73                    Armenia  40.069099   45.038189                 3.71
# 47                  Argentina -38.416097  -63.616672                 8.22
# 92                     Angola -11.202692   17.873887                 5.35
# 78                    Algeria  28.033886    1.659626                 0.58
# 69                    Albania  41.153332   20.168331                 4.70
# 117               Afghanistan  33.939110   67.709953                 0.01
#
#      Happiness
# 122      3.582
# 115      3.964
# 89       6.382
# 39       5.358
# 97       4.657
# 12       6.965
# 67       4.340
# 63       4.758
# 22       6.489
# 18       7.632
# 120      4.350
# 32       5.739
# 87       6.167
# 80       4.419
# 77       5.973
# 56       5.302
# 10       7.555
# 29       5.762
# 42       5.321
# 53       7.072
# 65       6.260
# 60       5.246
# 46       6.476
# 125      4.301
# 131      3.083
# 17       7.328
# 107      4.975
# 106      4.433
# 132      2.905
# 118      4.424
# 49       4.933
# 64       6.419
# 57       3.590
# 66       5.129
# 81       5.082
# 112      4.141
# 91       5.956
# 14       6.927
# 54       5.483
# 103      4.500
# 21       6.105
# 68       5.201
# 11       7.139
# 16       7.272
# 73       4.321
# 47       6.388
# 92       3.795
# 78       5.295
# 69       4.586
# 117      3.632

# %%
# Configure gmaps 
gmaps.configure(api_key=g_key)

# %%
# Store latitude and longitude in locations
locations = happy_data[["Lat", "Lng"]]

# Store data
consumption = happy_data["Alcohol Consumption"]


# Set center and zoom
#my_center = (locations.iloc[0]["Lat"], locations.iloc[0]["Lng"])
fig = gmaps.figure()


# Create and add layer
heat_layer = gmaps.heatmap_layer(locations, weights=consumption, dissipating=False, max_intensity=9, point_radius=3)

fig.add_layer(heat_layer)

# Display
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Store latitude and longitude in locations
locations = happy_data[["Lat", "Lng"]]

# Store data
consumption = happy_data["Happiness"]


# Set center and zoom
#my_center = (locations.iloc[0]["Lat"], locations.iloc[0]["Lng"])
fig = gmaps.figure()


# Create and add layer
heat_layer = gmaps.heatmap_layer(locations, weights=consumption, dissipating=False, max_intensity=7, point_radius=3)

fig.add_layer(heat_layer)

# Display
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Create, layer zoom and cetner 
my_center = (locations.iloc[8]["Lat"], locations.iloc[8]["Lng"])
hotel_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig = gmaps.figure(zoom_level=2, center=my_center)
